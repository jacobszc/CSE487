# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset = pd.read_csv("LC_DS.csv")

# %%
# Remove duplicates 
before = dataset.shape
dataset = dataset.drop_duplicates()
after = dataset.shape

print("Before:", before)
print("After :", after)
# Out:
# Before: (890000, 17)
# After : (890000, 17)

# %%
# Normalize text
dataset["gender"] = dataset["gender"].str.lower().str.strip()
dataset["smoking_status"] = dataset["smoking_status"].str.lower().str.strip()
dataset[["gender", "smoking_status"]].head()
# Out:
#    gender  smoking_status
# 0    male  passive smoker
# 1  female  passive smoker
# 2  female   former smoker
# 3  female  passive smoker
# 4    male  passive smoker

# %%
# Convert yes/no to 1/0
dataset["family_history"] = dataset["family_history"].replace({"Yes": 1, "No": 0})
dataset["family_history"] = pd.to_numeric(dataset["family_history"], errors="coerce")
dataset["family_history"].value_counts()
# Out:
# C:\Users\mets2\AppData\Local\Temp\ipykernel_12428\3169185852.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset["family_history"] = dataset["family_history"].replace({"Yes": 1, "No": 0})
# family_history
# 0    445181
# 1    444819
# Name: count, dtype: int64

# %%
# Check for missing values
dataset.isnull().sum()
# Out:
# id                    0
# age                   0
# gender                0
# country               0
# diagnosis_date        0
# cancer_stage          0
# family_history        0
# smoking_status        0
# bmi                   0
# cholesterol_level     0
# hypertension          0
# asthma                0
# cirrhosis             0
# other_cancer          0
# treatment_type        0
# end_treatment_date    0
# survived              0
# dtype: int64

# %%
# Fix data types (dates)
dataset["diagnosis_date"] = pd.to_datetime(dataset["diagnosis_date"])
dataset["end_treatment_date"] = pd.to_datetime(dataset["end_treatment_date"])
dataset[["diagnosis_date", "end_treatment_date"]].dtypes
# Out:
# diagnosis_date        datetime64[ns]
# end_treatment_date    datetime64[ns]
# dtype: object

# %%
# Filter by date 
dataset = dataset[dataset["diagnosis_date"] >= "2015-01-01"]
dataset["diagnosis_date"].min(), dataset["diagnosis_date"].max(), dataset.shape
# Out:
# (Timestamp('2015-01-01 00:00:00'),
#  Timestamp('2024-05-30 00:00:00'),
#  (838231, 17))

# %%
dataset.to_csv("LC_DS_cleaned.csv", index=False)

# %%
# Create a bar chart: Smoking Status vs. Survived
def smoking_bar_chart():
    plt.figure(figsize=(8, 5))
    ax = sns.countplot(data=dataset, x="smoking_status", hue="survived")
    plt.title("Smoking Status vs. Survived")
    plt.xlabel("Smoking Status")
    plt.ylabel("Number of Lung Cancer Patients")
    plt.legend(title="Survived", labels=["No", "Yes"])
    
    # Add counts on top of bars
    for p in ax.patches:
        height = int(p.get_height())
        ax.annotate(height, (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='bottom', fontsize=10, color='black')
    plt.show()
    # print(pd.crosstab(dataset['smoking_status'], dataset['survived']))

smoking_bar_chart()

# %%
# Create a histogram: Age Distribution of Lung Cancer Patients

def age_histogram():
    plt.figure(figsize=(8,5))
    sns.histplot(dataset["age"], bins=30, kde=True)
    plt.title("Age Distribution of Lung Cancer Patients")
    plt.xlabel("Age")
    plt.ylabel("Number of Diagnosis")
    plt.show()

age_histogram()

# %%
dataset.columns
# Out:
# Index(['id', 'age', 'gender', 'country', 'diagnosis_date', 'cancer_stage',
#        'family_history', 'smoking_status', 'bmi', 'cholesterol_level',
#        'hypertension', 'asthma', 'cirrhosis', 'other_cancer', 'treatment_type',
#        'end_treatment_date', 'survived'],
#       dtype='object')

# %%
sample_df = dataset.sample(n=1000, random_state=42)

# %%
plt.figure(figsize=(8, 6))
colors = sample_df['survived'].map({0: 'red', 1: 'green'})  # red for died, green for survived
plt.scatter(sample_df['age'], sample_df['bmi'], c=colors, alpha=0.6)
plt.xlabel('Age')
plt.ylabel('BMI')
plt.title('Age vs BMI Colored by Survival')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,6))
ax = sns.countplot(
    data=dataset,
    x='cancer_stage',
    hue='survived',
    palette={0: "#e61f1f", 1: "#088d1f"},  
    order=['Stage I', 'Stage II', 'Stage III', 'Stage IV']
)

# Add count numbers on bars
for container in ax.containers:
    ax.bar_label(container, fmt='%d', padding=2)

plt.title('Patient Count by Cancer Stage and Survival', pad=15)
plt.xlabel('Cancer Stage')
plt.ylabel('Number of Patients')
plt.legend(title='Survived', labels=['No', 'Yes'], framealpha=0.9)

plt.grid(axis='y', alpha=0.2)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,6))
ax = sns.barplot(
    data=dataset,
    x='treatment_type',
    y='survived',
    estimator=lambda x: np.mean(x) * 100,
    errorbar=None,
    palette='viridis'
)

# Add percentage labels
for p in ax.patches:
    ax.annotate(
        f"{p.get_height():.1f}%", 
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center', 
        va='center', 
        xytext=(0, 5),
        textcoords='offset points'
    )

plt.title('Survival Rate by Treatment Type')
plt.ylabel('Survival Rate (%)')
plt.xlabel('Treatment Type')
plt.ylim(0, 25)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\mets2\AppData\Local\Temp\ipykernel_12428\2566502978.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
plt.figure(figsize=(8,6))
sns.barplot(
    data=dataset,
    x='cancer_stage',
    y='survived',
    hue='treatment_type',
    estimator=lambda x: np.mean(x) * 100,
    order=['Stage I', 'Stage II', 'Stage III', 'Stage IV'],
    errorbar=None,
    palette='viridis'
)

plt.title('Survival Rate by Cancer Stage and Treatment Type')
plt.ylabel('Survival Rate (%)')
plt.xlabel('Cancer Stage')
plt.legend(title='Treatment Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.ylim(0, 25)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()
